# %%
import pandas as pd
df=pd.read_csv("C:/datasets/Sports Analytics Data set.csv",encoding='utf-8',index_col=0)
df
# Out:
#                  Age     Nationality  Overall Score  Potential         Club  \
# Name
# David Neres       21          Brazil             79         86         Ajax
# N. Tagliafico     25       Argentina             80         82         Ajax
# H. Bandé          19    Burkina Faso             72         84         Ajax
# V. Černý          20  Czech Republic             68         75         Ajax
# L. Orejuela       22        Colombia             67         73         Ajax
# ...              ...             ...            ...        ...          ...
# Marcos Llorente   23           Spain             79         87  Real Madrid
# K. Navas          31      Costa Rica             87         87  Real Madrid
# T. Courtois       26         Belgium             89         90  Real Madrid
# Kiko Casilla      31           Spain             79         79  Real Madrid
# L. Zidane         20          France             62         71  Real Madrid
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, David Neres to L. Zidane
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       342 non-null    int64
#  1   Nationality               342 non-null    object
#  2   Overall Score             342 non-null    int64
#  3   Potential                 342 non-null    int64
#  4   Club                      342 non-null    object
#  5   League                    342 non-null    object
#  6   Value                     342 non-null    object
#  7   Wage                      342 non-null    object
#  8   Preferred Foot            342 non-null    object
#  9   International Reputation  342 non-null    int64
#  10  Weak Foot                 342 non-null    int64
#  11  Skill Moves               342 non-null    int64
#  12  Work Rate                 342 non-null    object
# ...

# %%
df.loc["L. Messi"]
# Out:
# Age                         31
# Nationality          Argentina
# Overall Score               94
# Potential                   94
# Club              FC Barcelona
#                       ...
# GKHandling                  11
# GKKicking                   15
# GKPositioning               14
# GKReflexes                   8
# Release Clause         €226.5M
# Name: L. Messi, Length: 80, dtype: object

# %% [markdown]
# # Filtering columns of players less than or equal to 26 yrs

# %%
dff = df[df["Age"]<=26]

# %%
dff
# Out:
#                  Age     Nationality  Overall Score  Potential         Club  \
# Name
# David Neres       21          Brazil             79         86         Ajax
# N. Tagliafico     25       Argentina             80         82         Ajax
# H. Bandé          19    Burkina Faso             72         84         Ajax
# V. Černý          20  Czech Republic             68         75         Ajax
# L. Orejuela       22        Colombia             67         73         Ajax
# ...              ...             ...            ...        ...          ...
# Fidalgo           21           Spain             65         75  Real Madrid
# Manu Hernando     19           Spain             64         76  Real Madrid
# Marcos Llorente   23           Spain             79         87  Real Madrid
# T. Courtois       26         Belgium             89         90  Real Madrid
# L. Zidane         20          France             62         71  Real Madrid
#
# ...

# %%
df["Club"].value_counts()
# Out:
# Manchester United    33
# Chelsea              33
# Arsenal              33
# Liverpool            33
# Real Madrid          33
# FC Barcelona         33
# Manchester City      33
# Ajax                 30
# FC Bayern München    29
# Milan                27
# Juventus             25
# Name: Club, dtype: int64

# %%
df["League"].value_counts()
# Out:
# Premier League    165
# La Liga            66
# Serie A            52
# Eredivisie         30
# Bundesliga         29
# Name: League, dtype: int64

# %%
df["Position"].value_counts()
# Out:
# CB     41
# CM     41
# GK     38
# LB     29
# ST     28
# RB     26
# CAM    19
# RW     18
# LW     16
# CDM    14
# RCB    12
# RM     11
# LM     10
# RCM     8
# LCB     8
# LCM     7
# LDM     4
# RAM     2
# RDM     2
# LAM     2
# RS      2
# LF      2
# RF      1
# LS      1
# Name: Position, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, David Neres to L. Zidane
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       342 non-null    int64
#  1   Nationality               342 non-null    object
#  2   Overall Score             342 non-null    int64
#  3   Potential                 342 non-null    int64
#  4   Club                      342 non-null    object
#  5   League                    342 non-null    object
#  6   Value                     342 non-null    object
#  7   Wage                      342 non-null    object
#  8   Preferred Foot            342 non-null    object
#  9   International Reputation  342 non-null    int64
#  10  Weak Foot                 342 non-null    int64
#  11  Skill Moves               342 non-null    int64
#  12  Work Rate                 342 non-null    object
# ...

# %%
list=["Nationality","Preferred Foot","International Reputation","Weak Foot","Work Rate","Body Type","Loaned From","Height","Weight","LS","ST","RS","LW","LF","CF","RF","LAM","CAM","RAM","LM","LCM","CM","RCM","RM","LWB","LDM","CDM","RDM","RWB","LB","LCB","CB","RCB","RB","Crossing","Finishing","Volleys","Dribbling","GKDiving","GKHandling","GKKicking","GKPositioning","GKReflexes"]

# %%
dff.drop(list,axis=1,inplace=True)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:4164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dff
# Out:
#                  Age  Overall Score  Potential         Club      League  \
# Name
# David Neres       21             79         86         Ajax  Eredivisie
# N. Tagliafico     25             80         82         Ajax  Eredivisie
# H. Bandé          19             72         84         Ajax  Eredivisie
# V. Černý          20             68         75         Ajax  Eredivisie
# L. Orejuela       22             67         73         Ajax  Eredivisie
# ...              ...            ...        ...          ...         ...
# Fidalgo           21             65         75  Real Madrid     La Liga
# Manu Hernando     19             64         76  Real Madrid     La Liga
# Marcos Llorente   23             79         87  Real Madrid     La Liga
# T. Courtois       26             89         90  Real Madrid     La Liga
# L. Zidane         20             62         71  Real Madrid     La Liga
#
#                   Value   Wage  Skill Moves Position  Contract Valid Until  \
# Name
# ...

# %%
df["Position"].value_counts()
# Out:
# CB     41
# CM     41
# GK     38
# LB     29
# ST     28
# RB     26
# CAM    19
# RW     18
# LW     16
# CDM    14
# RCB    12
# RM     11
# LM     10
# RCM     8
# LCB     8
# LCM     7
# LDM     4
# RAM     2
# RDM     2
# LAM     2
# RS      2
# LF      2
# RF      1
# LS      1
# Name: Position, dtype: int64

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226 entries, David Neres to L. Zidane
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   226 non-null    int64
#  1   Overall Score         226 non-null    int64
#  2   Potential             226 non-null    int64
#  3   Club                  226 non-null    object
#  4   League                226 non-null    object
#  5   Value                 226 non-null    object
#  6   Wage                  226 non-null    object
#  7   Skill Moves           226 non-null    int64
#  8   Position              226 non-null    object
#  9   Contract Valid Until  226 non-null    int64
#  10  RW                    205 non-null    float64
#  11  HeadingAccuracy       226 non-null    int64
#  12  ShortPassing          226 non-null    int64
#  13  Curve                 226 non-null    int64
#  14  FKAccuracy            226 non-null    int64
# ...

# %%
df["Contract Valid Until"].value_counts()
# Out:
# 2021     87
# 2019     68
# 2022     67
# 2020     59
# 2023     46
# 2024      6
# 43646     5
# 2025      3
# 2018      1
# Name: Contract Valid Until, dtype: int64

# %%
dff["RW"].isnull().sum()
# Out:
# 21

# %% [markdown]
# # INCLUDING PLAYERS WHICH ARE LS,RS,RW (Focussing on Messi's position)

# %%
dff["Position"]=="RW"
# Out:
# Name
# David Neres         True
# N. Tagliafico      False
# H. Bandé           False
# V. Černý            True
# L. Orejuela        False
#                    ...
# Fidalgo            False
# Manu Hernando      False
# Marcos Llorente    False
# T. Courtois        False
# L. Zidane          False
# Name: Position, Length: 226, dtype: bool

# %%
dff["Position"]=="LS"
# Out:
# Name
# David Neres        False
# N. Tagliafico      False
# H. Bandé           False
# V. Černý           False
# L. Orejuela        False
#                    ...
# Fidalgo            False
# Manu Hernando      False
# Marcos Llorente    False
# T. Courtois        False
# L. Zidane          False
# Name: Position, Length: 226, dtype: bool

# %%
dff["Position"]=="RS"
# Out:
# Name
# David Neres        False
# N. Tagliafico      False
# H. Bandé           False
# V. Černý           False
# L. Orejuela        False
#                    ...
# Fidalgo            False
# Manu Hernando      False
# Marcos Llorente    False
# T. Courtois        False
# L. Zidane          False
# Name: Position, Length: 226, dtype: bool

# %%
dff=dff[(dff["Position"]=="RW") | (dff["Position"]=="RS") | (dff["Position"]=="LS")]
dff
# Out:
#                 Age  Overall Score  Potential               Club  \
# Name
# David Neres      21             79         86               Ajax
# V. Černý         20             68         75               Ajax
# Lucas Piazon     24             72         77            Chelsea
# O. Dembélé       21             83         92       FC Barcelona
# Malcom           21             82         89       FC Barcelona
# Guillem Jaime    19             64         80       FC Barcelona
# B. Adekanye      19             60         80          Liverpool
# R. Sterling      23             86         89    Manchester City
# Bernardo Silva   23             86         91    Manchester City
# T. Chong         18             65         85  Manchester United
# Suso             24             83         86              Milan
# P. Cutrone       20             77         89              Milan
# Marco Asensio    22             85         92        Real Madrid
#
# ...

# %% [markdown]
# # MESSI DETAILS FOR COMPARING WITH OTHER PLAYERS

# %% [markdown]
# ### An interesting thing in the dataset is that for all players, their points for a particular position on the Left side is the same as their points for the same position on the center or the right.
#
# ### For eg- Points for LW, RW are the same for all players (checked in the csv dataset itself).
#
# ### Continuing with this analysis, the only unique positions are RF, RW, RCM, RS, RAM, RWB, RDM, RB, RCB (Have chosen the right counterparts only in this list,)

# %%
df.reset_index(inplace = True)
df.head()
# Out:
#             Name  Age     Nationality  Overall Score  Potential  Club  \
# 0    David Neres   21          Brazil             79         86  Ajax
# 1  N. Tagliafico   25       Argentina             80         82  Ajax
# 2       H. Bandé   19    Burkina Faso             72         84  Ajax
# 3       V. Černý   20  Czech Republic             68         75  Ajax
# 4    L. Orejuela   22        Colombia             67         73  Ajax
#
#        League  Value  Wage Preferred Foot  ...  Composure  Marking  \
# 0  Eredivisie   €18M  €18K           Left  ...         78       32
# 1  Eredivisie   €15M  €20K           Left  ...         73       78
# 2  Eredivisie  €5.5M   €7K          Right  ...         63       22
# 3  Eredivisie  €1.3M   €6K           Left  ...         62       27
# 4  Eredivisie  €875K   €5K          Right  ...         60       58
#
#    StandingTackle SlidingTackle GKDiving GKHandling GKKicking  GKPositioning  \
# ...

# %%
df_analysis = df[["Name", "Age", "Club", "RF", "RS", "RW", "RAM", "RCM", "Crossing", "Finishing", "HeadingAccuracy", "ShortPassing", "Volleys", "Dribbling", "Curve", "FKAccuracy", "LongPassing", "BallControl", "Acceleration", "SprintSpeed", "Agility", "Reactions", "Balance", "ShotPower", "Jumping", "Stamina", "Strength", "LongShots", "Aggression", "Interceptions", "Positioning", "Vision", "Penalties", "Composure"]]
df_analysis.dropna(inplace = True) #To remove the columns with missing data that are all goalkeepers, actually
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_analysis.reset_index(inplace = True, drop = True)
df_analysis
# Out:
#                 Name  Age         Club    RF    RS    RW   RAM   RCM  \
# 0        David Neres   21         Ajax  78.2  73.2  78.2  78.2  70.2
# 1      N. Tagliafico   25         Ajax  70.2  68.2  72.2  70.2  71.2
# 2           H. Bandé   19         Ajax  71.2  69.2  71.2  70.2  63.2
# 3           V. Černý   20         Ajax  67.2  63.2  68.2  67.2  59.2
# 4        L. Orejuela   22         Ajax  60.2  58.2  61.2  60.2  60.2
# ..               ...  ...          ...   ...   ...   ...   ...   ...
# 299     Javi Sánchez   21  Real Madrid  44.2  45.2  44.2  45.2  50.2
# 300          Fidalgo   21  Real Madrid  62.2  57.2  63.2  64.2  64.2
# 301    Manu Hernando   19  Real Madrid  52.2  51.2  52.2  52.2  54.2
# 302         T. Kroos   28  Real Madrid  82.3  78.3  81.3  84.3  86.3
# 303  Marcos Llorente   23  Real Madrid  66.2  61.2  65.2  70.2  75.2
#
#      Crossing  Finishing  ...  Jumping  Stamina  Strength  LongShots  \
# ...

# %% [markdown]
# # REMOVING PLAYERS WHICH ARE FROM FC BARCLEONA

# %%
dff=dff[dff["Club"]!="FC Barcelona"]
df_analysis = df_analysis[df_analysis["Club"] != "FC Barcelona"]
dff
# Out:
#                 Age  Overall Score  Potential               Club  \
# Name
# David Neres      21             79         86               Ajax
# V. Černý         20             68         75               Ajax
# Lucas Piazon     24             72         77            Chelsea
# B. Adekanye      19             60         80          Liverpool
# R. Sterling      23             86         89    Manchester City
# Bernardo Silva   23             86         91    Manchester City
# T. Chong         18             65         85  Manchester United
# Suso             24             83         86              Milan
# P. Cutrone       20             77         89              Milan
# Marco Asensio    22             85         92        Real Madrid
#
#                         League   Value   Wage  Skill Moves Position  \
# Name
# David Neres         Eredivisie    €18M   €18K            5       RW
# V. Černý            Eredivisie   €1.3M    €6K            3       RW
# ...

# %%
df.loc[99]
# Out:
# Name               L. Messi
# Age                      31
# Nationality       Argentina
# Overall Score            94
# Potential                94
#                     ...
# GKHandling               11
# GKKicking                15
# GKPositioning            14
# GKReflexes                8
# Release Clause      €226.5M
# Name: 99, Length: 81, dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall Score', 'Potential', 'Club',
#        'League', 'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
# ...

# %%
df_analysis.columns
# Out:
# Index(['Name', 'Age', 'Club', 'RF', 'RS', 'RW', 'RAM', 'RCM', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure'],
#       dtype='object')

# %%
df_analysis["Diff from Messi"] = (df_analysis["Composure"] - df.loc[99, "Composure"])**2

#The below list in the for loop are the attributes that we are comparing each player against Messi with.
for i in ["RF", "RS", "RW", "RAM", "RCM", 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling','Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration','SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower','Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression','Interceptions', 'Positioning', 'Vision', 'Penalties']:
    df_analysis["Diff from Messi"] += (df_analysis[i] - df.loc[99, i])**2

df_analysis
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                 Name  Age         Club    RF    RS    RW   RAM   RCM  \
# 0        David Neres   21         Ajax  78.2  73.2  78.2  78.2  70.2
# ...

# %%
df_analysis.sort_values(by = "Diff from Messi", inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_analysis
# Out:
#             Name  Age               Club    RF    RS    RW   RAM   RCM  \
# 146    P. Dybala   24           Juventus  86.3  83.3  87.3  87.3  79.3
# 58     E. Hazard   27            Chelsea  88.3  83.3  89.3  89.3  82.3
# 125    A. Robben   34  FC Bayern München  84.3  80.3  84.3  83.3  76.3
# 199    S. Agüero   30    Manchester City  87.3  86.3  86.3  85.3  76.3
# 198    R. Mahrez   27    Manchester City  82.3  77.3  84.3  83.3  77.3
# ..           ...  ...                ...   ...   ...   ...   ...   ...
# 274     S. Simič   23              Milan  45.2  45.2  45.2  46.2  52.2
# 57     Z. Medley   17            Arsenal  39.2  40.2  38.2  39.2  43.2
# 139       L. Mai   18  FC Bayern München  40.2  43.2  40.2  40.2  45.2
# 192  N. Phillips   21          Liverpool  39.2  41.2  38.2  40.2  45.2
# 81      M. Guehi   17            Chelsea  38.2  40.2  38.2  37.2  40.2
#
#      Crossing  Finishing  ...  Stamina  Strength  LongShots  Aggression  \
# ...

# %%
df_analysis = df_analysis[df_analysis["Age"] <= 26]
df_analysis = df_analysis[df_analysis["Club"] != "FC Barcelona"]
df_analysis
# Out:
#               Name  Age               Club    RF    RS    RW   RAM   RCM  \
# 146      P. Dybala   24           Juventus  86.3  83.3  87.3  87.3  79.3
# 281  Marco Asensio   22        Real Madrid  83.3  79.3  83.3  83.3  79.3
# 133   J. Rodríguez   26  FC Bayern München  83.3  80.3  84.3  85.3  81.3
# 193        L. Sané   22    Manchester City  84.2  82.2  84.2  82.2  74.2
# 164       M. Salah   26          Liverpool  86.3  83.3  87.3  86.3  80.3
# ..             ...  ...                ...   ...   ...   ...   ...   ...
# 274       S. Simič   23              Milan  45.2  45.2  45.2  46.2  52.2
# 57       Z. Medley   17            Arsenal  39.2  40.2  38.2  39.2  43.2
# 139         L. Mai   18  FC Bayern München  40.2  43.2  40.2  40.2  45.2
# 192    N. Phillips   21          Liverpool  39.2  41.2  38.2  40.2  45.2
# 81        M. Guehi   17            Chelsea  38.2  40.2  38.2  37.2  40.2
#
#      Crossing  Finishing  ...  Stamina  Strength  LongShots  Aggression  \
# ...

# %% [markdown]
# # Problem Statement 1 OVER
#
# # The 3 players for recommendation based on their similarity with Messi and fulfilling the given criteria are:
# ## 1) Paulo Dybala
# ## 2) Marco Asensio
# ## 3) James Rodríguez
#
#
#
#
# (Note: FC Barcelona, being a large team, can afford to shell out a lot of money for a replacement of a player of Messi's caliber. Hence, the club can buy out these players from their current teams by paying their transfer clauses.)

# %%
df_predict = df[(df["Name"] == "P. Dybala") | (df["Name"] == "Marco Asensio") | (df["Name"] == "J. Rodríguez")]
df_predict
# Out:
#               Name  Age Nationality  Overall Score  Potential  \
# 146   J. Rodríguez   26    Colombia             88         89
# 163      P. Dybala   24   Argentina             89         94
# 315  Marco Asensio   22       Spain             85         92
#
#                   Club      League   Value   Wage Preferred Foot  ...  \
# 146  FC Bayern München  Bundesliga  €69.5M  €315K           Left  ...
# 163           Juventus     Serie A    €89M  €205K           Left  ...
# 315        Real Madrid     La Liga    €54M  €215K           Left  ...
#
#      Composure  Marking  StandingTackle SlidingTackle GKDiving GKHandling  \
# 146         87       52              41            44       15         15
# 163         84       23              20            20        5          4
# 315         83       40              42            39       13          9
#
#     GKKicking  GKPositioning GKReflexes Release Clause
# 146        15              5         14            NaN
# ...

# %% [markdown]
# # Now, we move on to the 2nd Problem Statement

# %%
dff.reset_index(inplace = True)

# %%
df2_reqd = dff.drop(dff.index[2])
df2_reqd.reset_index(inplace = True, drop = True)
df2_reqd.head()
# Out:
#              Name  Age  Overall Score  Potential             Club  \
# 0     David Neres   21             79         86             Ajax
# 1        V. Černý   20             68         75             Ajax
# 2     B. Adekanye   19             60         80        Liverpool
# 3     R. Sterling   23             86         89  Manchester City
# 4  Bernardo Silva   23             86         91  Manchester City
#
#            League   Value   Wage  Skill Moves Position  ...  Aggression  \
# 0      Eredivisie    €18M   €18K            5       RW  ...          52
# 1      Eredivisie   €1.3M    €6K            3       RW  ...          47
# 2  Premier League   €450K    €7K            3       RW  ...          45
# 3  Premier League  €56.5M  €195K            4       RW  ...          38
# 4  Premier League  €59.5M  €180K            4       RW  ...          58
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# ...

# %%
df.head()
# Out:
#             Name  Age     Nationality  Overall Score  Potential  Club  \
# 0    David Neres   21          Brazil             79         86  Ajax
# 1  N. Tagliafico   25       Argentina             80         82  Ajax
# 2       H. Bandé   19    Burkina Faso             72         84  Ajax
# 3       V. Černý   20  Czech Republic             68         75  Ajax
# 4    L. Orejuela   22        Colombia             67         73  Ajax
#
#        League  Value  Wage Preferred Foot  ...  Composure  Marking  \
# 0  Eredivisie   €18M  €18K           Left  ...         78       32
# 1  Eredivisie   €15M  €20K           Left  ...         73       78
# 2  Eredivisie  €5.5M   €7K          Right  ...         63       22
# 3  Eredivisie  €1.3M   €6K           Left  ...         62       27
# 4  Eredivisie  €875K   €5K          Right  ...         60       58
#
#    StandingTackle SlidingTackle GKDiving GKHandling GKKicking  GKPositioning  \
# ...

# %%
df.reset_index(inplace = True)
df.head()
# Out:
#    index           Name  Age     Nationality  Overall Score  Potential  Club  \
# 0      0    David Neres   21          Brazil             79         86  Ajax
# 1      1  N. Tagliafico   25       Argentina             80         82  Ajax
# 2      2       H. Bandé   19    Burkina Faso             72         84  Ajax
# 3      3       V. Černý   20  Czech Republic             68         75  Ajax
# 4      4    L. Orejuela   22        Colombia             67         73  Ajax
#
#        League  Value  Wage  ... Composure  Marking  StandingTackle  \
# 0  Eredivisie   €18M  €18K  ...        78       32              32
# 1  Eredivisie   €15M  €20K  ...        73       78              78
# 2  Eredivisie  €5.5M   €7K  ...        63       22              41
# 3  Eredivisie  €1.3M   €6K  ...        62       27              20
# 4  Eredivisie  €875K   €5K  ...        60       58              66
#
#    SlidingTackle GKDiving GKHandling GKKicking GKPositioning  GKReflexes  \
# ...

# %%
#This is used to get the currency values in millions in float format, while earlier these were in string format.
for ind in df.index:
    t1 = df.loc[ind,'Value']
    t2 = df.loc[ind,'Release Clause']
    t3 = df.loc[ind, 'Wage']
    
    if type(df.loc[ind,'Value'])==str:
        if t1[-1]=='M':
            df.loc[ind,'Value']=float(t1[1:len(t1)-1])
        elif t1[-1]=='K':
            df.loc[ind,'Value']=float(t1[1:len(t1)-1])/1000
            
    if type(df.loc[ind,'Release Clause'])==str:
        if t2[-1]=='M':
            df.loc[ind,'Release Clause']=float(t2[1:len(t2)-1])
        elif t2[-1]=='K':
            df.loc[ind,'Release Clause']=float(t2[1:len(t2)-1])/1000
                     
    if type(df.loc[ind,'Wage'])==str:
        if t3[-1]=='M':
            df.loc[ind,'Wage']=float(t3[1:len(t3)-1])
        elif t3[-1]=='K':
            df.loc[ind,'Wage']=float(t3[1:len(t3)-1])/1000

# %%
df.head()
# Out:
#    index           Name  Age     Nationality  Overall Score  Potential  Club  \
# 0      0    David Neres   21          Brazil             79         86  Ajax
# 1      1  N. Tagliafico   25       Argentina             80         82  Ajax
# 2      2       H. Bandé   19    Burkina Faso             72         84  Ajax
# 3      3       V. Černý   20  Czech Republic             68         75  Ajax
# 4      4    L. Orejuela   22        Colombia             67         73  Ajax
#
#        League  Value   Wage  ... Composure  Marking  StandingTackle  \
# 0  Eredivisie     18  0.018  ...        78       32              32
# 1  Eredivisie     15   0.02  ...        73       78              78
# 2  Eredivisie    5.5  0.007  ...        63       22              41
# 3  Eredivisie    1.3  0.006  ...        62       27              20
# 4  Eredivisie  0.875  0.005  ...        60       58              66
#
#    SlidingTackle GKDiving GKHandling GKKicking GKPositioning  GKReflexes  \
# ...

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures

# %%
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     342 non-null    int64
#  1   Name                      342 non-null    object
#  2   Age                       342 non-null    int64
#  3   Nationality               342 non-null    object
#  4   Overall Score             342 non-null    int64
#  5   Potential                 342 non-null    int64
#  6   Club                      342 non-null    object
#  7   League                    342 non-null    object
#  8   Value                     342 non-null    object
#  9   Wage                      342 non-null    object
#  10  Preferred Foot            342 non-null    object
#  11  International Reputation  342 non-null    int64
#  12  Weak Foot                 342 non-null    int64
#  13  Skill Moves               342 non-null    int64
# ...

# %%
df2 =  df[["Name", "Age", "League", "Overall Score", "Potential", "Value", "Wage", "International Reputation", "Position", "Release Clause"]]
df2.head()
# Out:
#             Name  Age      League  Overall Score  Potential  Value   Wage  \
# 0    David Neres   21  Eredivisie             79         86     18  0.018
# 1  N. Tagliafico   25  Eredivisie             80         82     15   0.02
# 2       H. Bandé   19  Eredivisie             72         84    5.5  0.007
# 3       V. Černý   20  Eredivisie             68         75    1.3  0.006
# 4    L. Orejuela   22  Eredivisie             67         73  0.875  0.005
#
#    International Reputation Position Release Clause
# 0                         2       RW           28.8
# 1                         2       LB           22.1
# 2                         1       LW            8.8
# 3                         1       RW              2
# 4                         1       RB            1.4

# %%
df2 = df2[df2["League"] == "La Liga"]
df2.drop(axis = 1, columns = "League", inplace = True)
df2.head()
# Out:
#               Name  Age  Overall Score  Potential  Value   Wage  \
# 96      Jordi Alba   29             87         87     38   0.25
# 97      O. Dembélé   21             83         92     40  0.155
# 98   Nélson Semedo   24             81         86     20  0.125
# 99        L. Messi   31             94         94  110.5  0.565
# 100         Malcom   21             82         89   31.5   0.14
#
#      International Reputation Position Release Clause
# 96                          3       LB           77.9
# 97                          3       RW             90
# 98                          2       RB           42.5
# 99                          5       RF          226.5
# 100                         2       RW           70.9

# %% [markdown]
# ## Now we have to use these variables to predict the wage for our new players.
# #### Let's see the correlation b/w different variables and Wages through scatterplots.

# %%
df2[~df2["Value"].apply(lambda x: isinstance(x, (int, float)))]
#df2[~df2["Wage"].apply(lambda x: isinstance(x, (int, float)))]
#df2[~df2["Release Clause"].apply(lambda x: isinstance(x, (int, float)))]

# The result shows us a flaw that all elements of df2 don't have their value, wage and Release Clause in the desired format.
# Since this is the only offending value, we can convert this into our desired form manually.

# The actual flaw in this is due to repeated entry of the same player "Rafinha" twice, in different clubs (Barcelona and FC Bayern München)!
# Out:
# Empty DataFrame
# Columns: [Name, Age, Overall Score, Potential, Value, Wage, International Reputation, Position, Release Clause]
# Index: []

# %%
df2.loc[110, "Value"] = 29.5
df2.loc[110, "Wage"] = 0.165
df2.loc[110, "Release Clause"] = 62.7
df2.loc[110]
# Out:
# Name                        Rafinha
# Age                              25
# Overall Score                    82
# Potential                        87
# Value                          29.5
# Wage                          0.165
# International Reputation          2
# Position                        CAM
# Release Clause                 62.7
# Name: 110, dtype: object

# %%
df2.reset_index(inplace = True, drop = True)
df2.head()
# Out:
#             Name  Age  Overall Score  Potential  Value   Wage  \
# 0     Jordi Alba   29             87         87     38   0.25
# 1     O. Dembélé   21             83         92     40  0.155
# 2  Nélson Semedo   24             81         86     20  0.125
# 3       L. Messi   31             94         94  110.5  0.565
# 4         Malcom   21             82         89   31.5   0.14
#
#    International Reputation Position Release Clause
# 0                         3       LB           77.9
# 1                         3       RW             90
# 2                         2       RB           42.5
# 3                         5       RF          226.5
# 4                         2       RW           70.9

# %%
for i in ["Age", "Overall Score", "Potential", "Value", "International Reputation", "Position", "Release Clause"]:
    plt.figure(figsize=(12,8))
    plt.scatter(df2[i], df2['Wage'], color='orange')
    plt.xlabel(i)
    plt.ylabel('Wage')
    plt.show()

# %% [markdown]
# # Insights from the graphs:
#
# 1) Quadratic/ Exponential relation between `Wage` and `Overall Score`. Also, `Overall Score` seems like a good predictor of `Wage` as can be inferred from the Problem Statement 2 as well.
#
# 2) `Wage` is also somewhat correlated with `Potential`, but the relation is more haphazard in nature.
#
# 3) `Wage` is also well correlated with `Value` and `Release Clause` of a player.
#
# 4) As `International Reputation` increases, `Wage` (at the least it's upper limit) also increases, as can be expected in real life too. `Wage` increases somewhat with `Age` too (years of experience of a player would be a better quantifier though :).
#
# 5) No real relation between `Wage` and `Position`. Hence, we'll not use `Position` in our analysis of Problem Statement 2.

# %%
import math
import numpy as np
from sklearn.metrics import r2_score
from sklearn import linear_model

# %%
df2.columns
# Out:
# Index(['Name', 'Age', 'Overall Score', 'Potential', 'Value', 'Wage',
#        'International Reputation', 'Position', 'Release Clause'],
#       dtype='object')

# %%
x = np.array(df2['Overall Score'],dtype=float)
y = np.array(df2['Wage'],dtype=float)
mymodel = np.poly1d(np.polyfit(x, y, 4))

# %%
X = df2[['Value','Release Clause','Age']]
Y = df2['Wage']
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=[20,12])
for i in df2.index:
    #print(d.loc[i,'Wage'],regr.predict([[d.loc[i,'Value'],d.loc[i,'Release Clause'],d.loc[i,'Age']]]),mymodel(d.loc[i,'Overall Score']))
    plt.scatter(df2.loc[i,'Wage'],regr.predict([[df2.loc[i,'Value'],
                                               df2.loc[i,'Release Clause'],df2.loc[i,'Age']]]),color='blue',marker='.')
    plt.scatter(df2.loc[i,'Wage'],mymodel(df2.loc[i,'Overall Score']),color='orange',marker='.')
myline = df2['Wage']
plt.plot(myline, myline,color='black')

#plt.legend()
# Blue dots: Linear regression
# Orange dots: Polynomial regression
# Black line: 45 deg line for comparison.

# %%
df_predict.reset_index(inplace = True, drop = True)

# %%
df_predict
# Out:
#             Name  Age Nationality  Overall Score  Potential  \
# 0   J. Rodríguez   26    Colombia             88         89
# 1      P. Dybala   24   Argentina             89         94
# 2  Marco Asensio   22       Spain             85         92
#
#                 Club      League   Value   Wage Preferred Foot  ...  \
# 0  FC Bayern München  Bundesliga  €69.5M  €315K           Left  ...
# 1           Juventus     Serie A    €89M  €205K           Left  ...
# 2        Real Madrid     La Liga    €54M  €215K           Left  ...
#
#    Composure  Marking  StandingTackle SlidingTackle GKDiving GKHandling  \
# 0         87       52              41            44       15         15
# 1         84       23              20            20        5          4
# 2         83       40              42            39       13          9
#
#   GKKicking  GKPositioning GKReflexes Release Clause
# 0        15              5         14            NaN
# ...

# %%
for ind in df_predict.index:
    t1 = df_predict.loc[ind,'Value']
    t2 = df_predict.loc[ind,'Release Clause']
    t3 = df_predict.loc[ind, 'Wage']
    
    if type(df_predict.loc[ind,'Value'])==str:
        if t1[-1]=='M':
            df_predict.loc[ind,'Value']=float(t1[1:len(t1)-1])
        elif t1[-1]=='K':
            df_predict.loc[ind,'Value']=float(t1[1:len(t1)-1])/1000
            
    if type(df_predict.loc[ind,'Release Clause'])==str:
        if t2[-1]=='M':
            df_predict.loc[ind,'Release Clause']=float(t2[1:len(t2)-1])
        elif t2[-1]=='K':
            df_predict.loc[ind,'Release Clause']=float(t2[1:len(t2)-1])/1000
                     
    if type(df_predict.loc[ind,'Wage'])==str:
        if t3[-1]=='M':
            df_predict.loc[ind,'Wage']=float(t3[1:len(t3)-1])
        elif t3[-1]=='K':
            df_predict.loc[ind,'Wage']=float(t3[1:len(t3)-1])/1000
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_predict.loc[0, "Release Clause"] = (df_predict.loc[0, "Wage"] - regr.coef_[0]*df_predict.loc[0, "Value"] - regr.coef_[2]*df_predict.loc[0, "Age"])/ regr.coef_[1]
# This has been done so as to impute the missing value of "Release Clause" of James Rodríguez.
df_predict
# Out:
#             Name  Age Nationality  Overall Score  Potential  \
# 0   J. Rodríguez   26    Colombia             88         89
# 1      P. Dybala   24   Argentina             89         94
# 2  Marco Asensio   22       Spain             85         92
#
#                 Club      League Value   Wage Preferred Foot  ...  Composure  \
# 0  FC Bayern München  Bundesliga  69.5  0.315           Left  ...         87
# 1           Juventus     Serie A    89  0.205           Left  ...         84
# 2        Real Madrid     La Liga    54  0.215           Left  ...         83
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling GKKicking  \
# 0       52              41            44       15         15        15
# 1       23              20            20        5          4         4
# 2       40              42            39       13          9         6
#
#    GKPositioning GKReflexes Release Clause
# 0              5         14         183.46
# ...

# %%
wage_list = []
for i in df_predict.index:
    wage1 = regr.predict([[df_predict.loc[i,'Value'], df_predict.loc[i,'Release Clause'], df_predict.loc[i,'Age']]])
    wage2 = mymodel(df_predict.loc[i,'Overall Score'])
    wage_list.append((wage1 + wage2)/2)

wage_list
# NOTE: The following wages are in Millions of Euros.
# Out:
# [array([0.23632208]), array([0.41997358]), array([0.20812984])]

# %% [markdown]
# # Hence, we obtain the estimates for wages to be paid to the selected players:
#
# ## 1) James Rodríguez : € 236K
# ## 2) P. Dybala : € 419K
# ## 3) Marco Asensio : € 208K

# %% [markdown]
# # Problem Statement 3 now:

# %%
df3 =  df[["Name", "Age", "League", "Overall Score", "Potential", "Value", "Wage", "International Reputation", "Position", "Release Clause"]]
df3
# Out:
#                 Name  Age      League  Overall Score  Potential  Value   Wage  \
# 0        David Neres   21  Eredivisie             79         86     18  0.018
# 1      N. Tagliafico   25  Eredivisie             80         82     15   0.02
# 2           H. Bandé   19  Eredivisie             72         84    5.5  0.007
# 3           V. Černý   20  Eredivisie             68         75    1.3  0.006
# 4        L. Orejuela   22  Eredivisie             67         73  0.875  0.005
# ..               ...  ...         ...            ...        ...    ...    ...
# 337  Marcos Llorente   23     La Liga             79         87     16   0.11
# 338         K. Navas   31     La Liga             87         87   30.5  0.195
# 339      T. Courtois   26     La Liga             89         90   53.5   0.24
# 340     Kiko Casilla   31     La Liga             79         79    7.5  0.105
# 341        L. Zidane   20     La Liga             62         71   0.35  0.009
#
# ...

# %%
for ind in df3.index:
    t1 = df3.loc[ind,'Value']
    t2 = df3.loc[ind,'Release Clause']
    t3 = df3.loc[ind, 'Wage']
    
    if type(df3.loc[ind,'Value'])==str:
        if t1[-1]=='M':
            df3.loc[ind,'Value']=float(t1[1:len(t1)-1])
        elif t1[-1]=='K':
            df3.loc[ind,'Value']=float(t1[1:len(t1)-1])/1000
            
    if type(df3.loc[ind,'Release Clause'])==str:
        if t2[-1]=='M':
            df3.loc[ind,'Release Clause']=float(t2[1:len(t2)-1])
        elif t2[-1]=='K':
            df3.loc[ind,'Release Clause']=float(t2[1:len(t2)-1])/1000
                     
    if type(df3.loc[ind,'Wage'])==str:
        if t3[-1]=='M':
            df3.loc[ind,'Wage']=float(t3[1:len(t3)-1])
        elif t3[-1]=='K':
            df3.loc[ind,'Wage']=float(t3[1:len(t3)-1])/1000

# %%
df3
# Out:
#                 Name  Age      League  Overall Score  Potential  Value   Wage  \
# 0        David Neres   21  Eredivisie             79         86     18  0.018
# 1      N. Tagliafico   25  Eredivisie             80         82     15   0.02
# 2           H. Bandé   19  Eredivisie             72         84    5.5  0.007
# 3           V. Černý   20  Eredivisie             68         75    1.3  0.006
# 4        L. Orejuela   22  Eredivisie             67         73  0.875  0.005
# ..               ...  ...         ...            ...        ...    ...    ...
# 337  Marcos Llorente   23     La Liga             79         87     16   0.11
# 338         K. Navas   31     La Liga             87         87   30.5  0.195
# 339      T. Courtois   26     La Liga             89         90   53.5   0.24
# 340     Kiko Casilla   31     La Liga             79         79    7.5  0.105
# 341        L. Zidane   20     La Liga             62         71   0.35  0.009
#
# ...

# %%
df3.dropna(inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in ["Potential", "Value", "Age", "Wage"]:
    plt.figure(figsize=(10,8))
    plt.scatter(df3[i],df3["Release Clause"])
    plt.xlabel(i)
    plt.ylabel("Release Clause")

# %% [markdown]
# # Insights from the graphs:
#
# #### 1) `Release Clause` is well correlated with `Value` and `Wage` through simple Linear Regression.
# #### 2) `Release Clause` is correlated quadratically with `Potential` of the players.
# #### 3) We'll not be using `Age` as a predictor for `Release Clause`.

# %%
X = df3[['Value','Wage']]
Y = df3['Release Clause']
model_linear = LinearRegression()
model_linear.fit(X, Y)
# Out:
# LinearRegression()

# %%
x = np.array(df3['Potential'],dtype=float)
y = np.array(df3['Release Clause'],dtype=float)

# %%
for i in range(1,5):
    mymodel = np.poly1d(np.polyfit(x, y, i))
    myline = np.linspace(min(x), max(x), 1000)
    plt.figure(figsize=[12,8])
    plt.scatter(x, y)
    plt.plot(myline, mymodel(myline),color='orange')
    plt.xlabel("Potential")
    plt.ylabel("Release Clause")
    plt.show()
    print(i,r2_score(y, mymodel(x)))
# Out:
# 1 0.5784681075640963
# 2 0.6908734607520937
# 3 0.6971536545251398
# 4 0.6971954485593055

# %% [markdown]
# ### We can safely choose a 4th order polynomial for prediction of `Release Clause` by Potential.

# %%
mymodel = np.poly1d(np.polyfit(x, y, 4))

# %%
Final_release_clause = []
for i in df_predict.index:
    rc1 = model_linear.predict([[df_predict.loc[i,'Value'], df_predict.loc[i,'Wage']]])
    rc2 = mymodel(df_predict.loc[i,'Potential'])
    Final_release_clause.append((rc1 + rc2)/2)

Final_release_clause
# Out:
# [array([106.69012673]), array([160.95171923]), array([112.39284641])]

# %% [markdown]
# # Hence, we obtain the estimates for Release Clauses to be paid to the selected players:
#
# ## 1) James Rodríguez : € 107M
# ## 2) P. Dybala : € 161M
# ## 3) Marco Asensio : € 112M

# %% [markdown]
# # Problem Statement 3 and the complete task is now over
